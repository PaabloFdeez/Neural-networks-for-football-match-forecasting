# %%
def rename_football_data_co_uk_premier(pd_series):
    pd_series = pd_series.replace({
         'Aston Villa':"PR001",
         'Blackburn':"PR002",
         'Bolton':"PR003",
         'Chelsea':"PR004",
         'Sunderland':"PR005",
         'Tottenham': "PR006",
         'Wigan': "PR007",
         'Wolves':"PR008",
         'Liverpool': "PR009",
         'Man United': "PR010",
         'Arsenal': "PR011",
         'Birmingham': "PR012",
         'Everton': "PR013",
         'Stoke': "PR014",
         'West Brom':"PR015",
         'West Ham':"PR016",
         'Fulham':"PR017",
         'Newcastle':"PR018",
         'Man City': "PR019",
         'Blackpool':"PR020",
         'QPR':"PR021",
         'Swansea':"PR022",
         'Norwich':"PR023",
         'Reading':"PR024",
         'Southampton':"PR025",
         'Crystal Palace':"PR026",
         'Hull':"PR027",
         'Cardiff':"PR028",
         'Leicester':"PR029",
         'Burnley':"PR030",
         'Bournemouth':"PR031",
         'Watford':"PR032",
         'Middlesbrough':"PR033",
         'Brighton':"PR034",
         'Huddersfield':"PR035",
         'Sheffield United':"PR036",
         'Leeds': "PR037",
         'Brentford':"PR038",
         "Nottingham Forest": "PR039",
         "Nott'm Forest":"PR039",
         "Luton Town" : "PR040",
         'Luton':"PR040",
         'Wigan': 'PR007',
         'Birmingham': 'PR012'
   })
    return pd_series

# %%
def rename_market_value_premier(pd_series):
    pd_series = pd_series.replace({
         'Chelsea FC': "PR004",
         'Manchester City':"PR019",
         'Manchester United':"PR010",
         'Liverpool FC':"PR009",
         'Arsenal FC':"PR011",
         'Tottenham Hotspur':"PR006",
         'Aston Villa':"PR001",
         'Everton FC':"PR013",
         'Sunderland AFC':"PR005",
         'West Ham United':"PR016",
         'Newcastle United':"PR018",
         'Fulham FC':"PR017",
         'Bolton Wanderers':"PR003",
         'Birmingham City':"PR012",
         'Stoke City':"PR014",
         'Blackburn Rovers':"PR002",
         'West Bromwich Albion':"PR015",
         'Wolverhampton Wanderers':"PR008",
         'Wigan Athletic':"PR007",
         'Blackpool FC':"PR020",
         'Queens Park Rangers':"PR021",
         'Swansea City':"PR022",
         'Norwich City':"PR023",
         'Southampton FC':"PR025",
         'Reading FC':"PR024",
         'Cardiff City':"PR028",
         'Crystal Palace':"PR026",
         'Hull City':"PR027",
         'Leicester City':"PR029",
         'Burnley FC':"PR030",
         'Watford FC':"PR032",
         'AFC Bournemouth':"PR031",
         'Middlesbrough FC':"PR033",
         'Brighton & Hove Albion':"PR034",
         'Huddersfield Town':"PR035",
         'Sheffield United':"PR036",
         'Leeds United':"PR037",
         'Brentford FC':"PR038",
         "Nottingham Forest": "PR039",
         'Nottingham Forest':"PR039",
         'Luton Town':"PR040",
         'Wigan': 'PR007',
         'Birmingham': 'PR012',
         'Leeds': "PR037",
    })
    return pd_series

# %%
def rename_fifa_stats_premier(pd_series):
    pd_series = pd_series.replace({
         'Chelsea':"PR004",
         'Manchester United':"PR010",
         'Manchester City':"PR019",
         'Arsenal':"PR011",
         'Liverpool':"PR009",
         'Tottenham Hotspur':"PR006",
         'Everton':"PR013",
         'Aston Villa':"PR001",
         'Fulham':"PR017",
         'Birmingham City':"PR012",
         'Sunderland':"PR005",
         'Bolton Wanderers':"PR003",
         'Blackburn Rovers':"PR002",
         'West Ham United':"PR016",
         'Stoke City':"PR014",
         'Newcastle United':"PR018",
         'Wolverhampton Wanderers':"PR008",
         'West Bromwich Albion':"PR015",
         'Wigan Athletic':"PR007",
         'Blackpool':"PR020",
         'Queens Park Rangers':"PR021",
         'Swansea City':"PR022",
         'Norwich City':"PR023",
         'Southampton':"PR025",
         'Reading':"PR024",
         'Hull City':"PR027",
         'Cardiff City':"PR028",
         'Crystal Palace':"PR026",
         'Leicester City':"PR029",
         'Burnley':"PR030",
         'Watford':"PR032",
         'Bournemouth':"PR031",
         'Middlesbrough':"PR033",
         'Brighton & Hove Albion':"PR034",
         'Huddersfield Town':"PR035",
         'AFC Bournemouth':"PR031",
         'Sheffield United':"PR036",
         'Leeds United':"PR037",
         'Brentford':"PR038",
         'Spurs':"PR006",
         "Luton Town": "PR040",
         'Manchester Utd':"PR010",
         'West Ham':"PR016",
         'Newcastle Utd':"PR018",
         'Wolves':"PR008",
         "Nott'm Forest":"PR039",
         "Nottingham Forest": "PR039",
         'Brighton':"PR034",
         "Luton": "PR040",
         "Norwich":"PR023",
         "Swansea":"PR022",
         "Cardiff":"PR028",
         "Newcastle":"PR018",
         "Tottenham":"PR006",
         "Leicester":"PR029",
         "Huddersfield":"PR035",
         "Wolverhampton":"PR008",
         'Wigan': 'PR007',
         'Birmingham': 'PR012',
         'Leeds': "PR037",
         
    })
    return pd_series
