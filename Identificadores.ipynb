# %%
def rename_column_football_data_co_uk(pd_series):
    pd_series = pd_series.replace({
    'Real Madrid La Liga':'ID002',
    'FC Barcelona La Liga':'ID005',
    'Atlético Madrid La Liga':'ID003', 
    'Real Sociedad La Liga':'ID006',
    'Athletic Club La Liga':'ID004', 
    'Real Betis La Liga':'ID007', 
    'Sevilla La Liga':'ID016',
    'Villarreal La Liga':'ID014', 
    'Girona La Liga':'ID001', 
    'Getafe La Liga':'ID010',
    'Celta de Vigo La Liga':'',
    'Mallorca La Liga':'ID017', 
    'Osasuna La Liga':'ID012',
    'Rayo Vallecano La Liga':'ID013', 
    'Almería La Liga':'ID020',
    'Cádiz La Liga':'ID018',
    'Valencia La Liga':'ID008',
    'Las Palmas La Liga':'ID009',
    'Granada La Liga':'ID019',
    'Deportivo Alavés La Liga':'ID011',
    'Espanyol La Liga':'ID021',
    'Real Valladolid La Liga':'ID022',
    'Elche La Liga':'ID023',
    'Levante La Liga':'ID024',
    'SD Eibar La Liga':'ID025',
    'Huesca La Liga':'ID026',
    'Leganés La Liga':'ID027',
    'Deportivo La Coruña La Liga':'ID028',
    'Málaga La Liga':'ID029',
    'Sporting Gijón La Liga':'ID030'    
})

# %%
def rename_column_bdfutbol(pd_series):
    pd_series = pd_series.replace({
    'Hercules': 'ID0031',
    'Levante': 'ID0024',
    'Malaga': 'ID0029',
    'Espanol': 'ID0021',
    'La Coruna': 'ID0028',
    'Mallorca': 'ID0015',
    'Osasuna': 'ID0012',
    'Santander': 'ID0032',
    'Sociedad': 'ID0006',
    'Ath Madrid': 'ID0003',
    'Ath Bilbao': 'ID0004',
    'Barcelona': 'ID0005',
    'Real Madrid': 'ID0002',
    'Valencia': 'ID0008',
    'Getafe': 'ID0010',
    'Sevilla': 'ID0016',
    'Sp Gijon': 'ID0030',
    'Villarreal': 'ID0014',
    'Zaragoza': 'ID0033',
    'Almeria': 'ID0020',
    'Granada': 'ID0019',
    'Betis': 'ID0007',
    'Vallecano': 'ID0013',
    'Celta': 'ID0017',
    'Valladolid': 'ID0022',
    'Elche': 'ID0023',
    'Eibar': 'ID0025',
    'Cordoba': 'ID0034',
    'Las Palmas': 'ID0009',
    'Leganes': 'ID0027',
    'Alaves': 'ID0011',
    'Girona': 'ID0001',
    'Huesca': 'ID0026',
    'Cadiz': 'ID0018'
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 data['HomeTeam'] = data['HomeTeam'].replace({
#       2     'Hercules': 'ID0031',
#       3     'Levante': 'ID0024',
#       4     'Malaga': 'ID0029',
#       5     'Espanol': 'ID0021',
#       6     'La Coruna': 'ID0028',
#       7     'Mallorca': 'ID0015',
#       8     'Osasuna': 'ID0012',
#       9     'Santander': 'ID0032',
#      10     'Sociedad': 'ID0006',
#      11     'Ath Madrid': 'ID0003',
#      12     'Ath Bilbao': 'ID0004',
#      13     'Barcelona': 'ID0005',
#      14     'Real Madrid': 'ID0002',
#      15     'Valencia': 'ID0008',
#      16     'Getafe': 'ID0010',
#      17     'Sevilla': 'ID0016',
#      18     'Sp Gijon': 'ID0030',
#      19     'Villarreal': 'ID0014',
#      20     'Zaragoza': 'ID0033',
#      21     'Almeria': 'ID0020',
#      22     'Granada': 'ID0019',
#      23     'Betis': 'ID0007',
#      24     'Vallecano': 'ID0013',
#      25     'Celta': 'ID0017',
#      26     'Valladolid': 'ID0022',
#      27     'Elche': 'ID0023',
#      28     'Eibar': 'ID0025',
#      29     'Cordoba': 'ID0034',
#      30     'Las Palmas': 'ID0009',
#      31     'Leganes': 'ID0027',
#      32     'Alaves': 'ID0011',
#      33     'Girona': 'ID0001',
#      34     'Huesca': 'ID0026',
#      35     'Cadiz': 'ID0018'
#      36 })
#
# NameError: name 'data' is not defined

# %%
def rename_column_fifaindex(pd_series):
    pd_series = pd_series.replace({
        'F.C. Barcelona': 'ID005',
        'Real Madrid C.F.':'ID002',
        'Valencia C.F.': 'ID008',
        'Atlético de Madrid': 'ID003',
        'Sevilla F.C.': 'ID016',
        'Villarreal C.F.': 'ID014',
        'R.C. Deportivo': 'ID028', 
        'Getafe C.F.': 'ID010', 
        'R.C.D. Espanyol': 'ID021',
        'Real Racing Club': 'ID032', 
        'Athletic Club de Bilbao': 'ID004', 
        'U.D. Almería': 'ID020',
        'Málaga C.F.': 'ID029', 
        'Real Valladolid C.F.': 'ID022', 
        'Real Zaragoza': 'ID033',
        'Club Atlético Osasuna': 'ID012', 
        'R.C.D. Mallorca': 'ID015',
        'Real Sporting de Gijón': 'ID030', 
        'C.D. Tenerife': 'ID035', 
        'Xerez C.D.':'ID036',
        'Real Madrid  ': 'ID002', 
        'Club Atlético de Madrid  ': 'ID003',
        'Sevilla Fútbol Club  ': 'ID016', 
        'Valencia    ': 'ID008', 
        'Villarreal    ': 'ID014',
        'Getafe    ': 'ID010', 
        'Real Club Deportivo de La Coruña  ':'ID028',
        'R.C.D. Espanyol de Barcelona  ': 'ID021', 
        'Real Sporting de Gijón  ': 'ID030',
        'Real Zaragoza  ': 'ID033', 
        'Real Club Deportivo Mallorca  ': 'ID015',
        'Unión Deportiva Almería  ': 'ID020', 
        'Real Racing Club  ': 'ID032', 
        'Hércules    ':'ID031',
        'Málaga    ': 'ID029',
        'Real Sociedad de Fútbol  ':'ID006',
        'Levante Unión Deportiva  ':'ID024',
        'Real Betis Balompié  ':'ID007',
        'Granada  ':'ID019',
        'Rayo Vallecano de Madrid  ':'ID013', 
        'FC Barcelona':'ID005',
        'Club Atlético de Madrid':'ID003',
        'Valencia  ':'ID008',
        'Málaga  ': 'ID029',
        'Sevilla Fútbol Club':'ID016',
        'Real Sociedad de Fútbol': 'ID006',
        'Real Betis Balompié': 'ID007',
        'Getafe  ':'ID010', 
        'RCD Espanyol de Barcelona': 'ID021',
        'Levante Unión Deportiva':'ID024',
        'Rayo Vallecano de Madrid':'ID013',
        'Real Valladolid  ':'ID022', 
        'Real Club Deportivo de La Coruña':'ID028',
        'Real Club Deportivo Mallorca':'ID015',
        'Real Club Celta de Vigo':'ID017',
        'Elche  ':'ID023', 
        'Unión Deportiva Almería':'ID020', 
        'Villarreal  ':'ID014', 
        'SD Eibar':'ID025',
        'Córdoba  ':'ID034',
        'Real Madrid CF':'ID002',
        'Atlético Madrid': 'ID003', 
        'Valencia CF': 'ID008',
        'Sevilla FC': 'ID016',
        'Villarreal CF': 'ID014',
        'Real Sociedad': 'ID006', 
        'RC Celta de Vigo':'ID017',
        'Málaga CF': 'ID029',
        'RC Deportivo de La Coruña':'ID028',
        'RCD Espanyol':'ID021',
        'Levante UD':'ID024',
        'Rayo Vallecano':'ID013',
        'Getafe CF':'ID010', 
        'Granada CF':'ID019',
        'UD Las Palmas':'ID009', 
        'CD Leganés':'ID027',
        'Deportivo Alavés':'ID011', 
        'CA Osasuna':'ID012',
        'Girona CF':'ID001', 
        'Real Madrid':'ID002', 
        'Real Betis':'ID007', 
        'Athletic Club':'ID004',
        'RC Celta':'ID017',
        'Girona FC':'ID001', 
        'D. Alavés':'ID011',
        'R. Valladolid CF':'ID022',
        'SD Huesca':'ID026',
        'RCD Mallorca':'ID015',
        'Cádiz CF':'ID018', 
        'Elche CF':'ID023', 
        'UD Almería':'ID020'})
    return pd_series

# %%
def rename_column_bdfutbol_ref(pd_series):
    pd_series = pd_series.replace({
        'Hércules': 'ID031',
        'Levante': 'ID024',
        'Málaga': 'ID029',
        'Espanyol': 'ID021',
        'Deportivo de La Coruña': 'ID028',
        'Mallorca': 'ID015',
        'Osasuna': 'ID012',
        'Racing de Santander': 'ID032',
        'Real Sociedad': 'ID006',
        'Atlético de Madrid': 'ID003',
        'Athletic Club': 'ID004',
        'Barcelona': 'ID005',
        'Real Madrid': 'ID002',
        'Valencia': 'ID008',
        'Getafe': 'ID010',
        'Sevilla': 'ID016',
        'Sporting de Gijón': 'ID030',
        'Villarreal': 'ID014',
        'Zaragoza': 'ID033',
        'Almería': 'ID020',
        'Granada': 'ID019',
        'Betis': 'ID007',
        'Rayo Vallecano': 'ID013',
        'Celta de Vigo': 'ID017',
        'Valladolid': 'ID022',
        'Elche': 'ID023',
        'Eibar': 'ID025',
        'Córdoba': 'ID034',
        'Las Palmas': 'ID009',
        'Leganés': 'ID027',
        'Alavés': 'ID011',
        'Girona': 'ID001',
        'Huesca': 'ID026',
        'Cádiz': 'ID018'})
    return pd_series
